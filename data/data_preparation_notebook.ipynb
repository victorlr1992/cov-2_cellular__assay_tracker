# %%
import pandas as pd
import json

# %%
data_df = pd.read_csv('database.csv')

# %%
data_df = data_df.fillna('Not Applicable')

# %%
data_df
# Out:
#           Compound Name Alternative name in publication  EC50 [uM]  \
# 0             ribavirin                  Not Applicable      109.5
# 1            nafamostat                          Buipel       22.5
# 2           penciclovir                  Not Applicable      95.96
# 3          nitazoxanide                  Not Applicable       2.12
# 4           chloroquine                  Not Applicable       1.13
# ..                  ...                             ...        ...
# 285  Hydroxychloroquine                  Not Applicable      0.733
# 286          Famotidine                  Not Applicable       >100
# 287          Ivermectin                  Not Applicable  2.2 - 2.8
# 288          Remdesivir                  Not Applicable       0.38
# 289           Darunavir                  Not Applicable       >100
#
#             Result        CC50 [uM]                              virus  \
# 0    Not Applicable            >400                      clinical nCoV
# ...

# %%
with open("database2.json", "w") as f:
    json.dump({"data": data_df.astype(str).values.tolist()}, f, indent=2)
